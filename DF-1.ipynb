# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline 
df = pd.read_excel('/home/evzen/Downloads/HSC.xlsx')
#df.isna().sum()
drop_first_row = df.drop(df.index[0]).drop(["File name", "Status (annotatable or not annotatable and reason)","Start date ", "Start time", "Finish date", "Finish time"], axis=1)
drop_first_row.head()
# Out:
#         Comment        Annotator's name  \
# 1         Tokio           Mládek Martin
# 2         Tokio           Mládek Martin
# 3  Tokio, APC17  Tran Anh Hoang Patrik
# 4         APC15  Tran Anh Hoang Patrik
# 5         Tokio           Novotná Adéla
#
#   Net time spent on video (Dyn. objects) Net time spent on video (RB)  \
# 1                               01:50:00                     01:00:00
# 2                               00:51:00                     00:53:00
# 3                               01:17:00                     02:28:00
# 4                               03:05:00                     00:00:00
# 5                               01:03:00                     01:08:00
#
#   Net time spent on video (total)  \
# 1                        02:50:00
# 2                        01:44:00
# 3                        03:45:00
# 4                        03:05:00
# 5                        02:11:00
#
#   Time for annotation corrections after not succeful validation  \
# ...

# %%
df1 = drop_first_row.fillna(0)
bool_array = df1["Rozdíl AQ vs. AO (kontrola pro anotátora)"]>0
df1 = df1[bool_array]

# %%
s = drop_first_row
num_frames = s["Number of frames"].fillna(0)
a_r = s["Annotation Ratio NET/1500fr [min]"].fillna(0)
s.plot.scatter(x = num_frames, y = a_r)
#bool_arr1 =
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-e3861d6a0b39> in <module>
#       2 num_frames = s["Number of frames"].fillna(0)
#       3 a_r = s["Annotation Ratio NET/1500fr [min]"].fillna(0)
# ----> 4 s.plot.scatter(x = num_frames, y = a_r)
#       5 #bool_arr1 =
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/plotting/_core.py in scatter(self, x, y, s, c, **kwds)
#    3459             ...                       colormap='viridis')
#    3460         """
# -> 3461         return self(kind='scatter', x=x, y=y, c=c, s=s, **kwds)
#    3462
#    3463     def hexbin(self, x, y, C=None, reduce_C_function=None, gridsize=None,
#
# ...
