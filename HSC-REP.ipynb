# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import pathlib
import pandas as pd
import numpy as np

"""Load data """
df = pd.read_excel(r'C:\Users\anotator\Desktop\VALIDACE_KPI\data\evidence\honda\HSC.xlsx')
#df = pd.read_excel('/home/evzen/Downloads/HSC.xlsx')

#df1 = df1[df1["Stav videa (info pro logistika a validátory)"] == "Zvalidované a validátorem uložené v archivu"]

# %%
df1 = df[df["Stav videa (info pro logistika a validátory)"] == "Zvalidované a validátorem uložené v archivu"]
df1 = df1[df1["Status (annotatable or not annotatable and reason)"] == "Annotatable"]


# date = "2019-07-20 00:00:00"

# df1["Date of first validation"] = df1["Date of first validation"].astype(str)
# df1["Date of second validation"] = df1["Date of second validation"].astype(str)
# df1["Date of third validation"] = df1["Date of third validation"].astype(str)


# df4 = df1[df1["Date of third validation"].str.contains(date)]#.drop(1, axis=1)

# #df4 = df4.drop(["Status (annotatable or not annotatable and reason)", "Stav videa (info pro logistika a validátory)"], axis=1)
# print(df4.shape[0])

# df3 = df1[df1["Date of second validation"].str.contains(date)]#.drop(1, axis=1)
# #df3 = df3.drop(["Status (annotatable or not annotatable and reason)", "Stav videa (info pro logistika a validátory)"], axis=1)
# # # print(df3.shape[0])

# # df2 = df1[df1["Date of first validation"] == "2019-07-20 00:00:00"  ]#.drop(1, axis=1)
# # # df2 = df2.drop(["Status (annotatable or not annotatable and reason)", "Stav videa (info pro logistika a validátory)"], axis=1)
# # # print(df2.shape[0])
# df2 = df1[df1["Date of first validation"].str.contains(date)]#.drop(1, axis=1)


df6 = df1.drop(["Status (annotatable or not annotatable and reason)", "Stav videa (info pro logistika a validátory)"], axis=1)
df6 = df6.set_index("Annotation Ratio NET/1500fr [min]")
df7 = df6.loc[(df6['Date of first validation'] == "2019-07-17 00:00:00")]
df8 = df6.loc[(df6['Date of second validation'] == "2019-07-17 00:00:00")]
df9 = df6.loc[(df6['Date of third validation'] == "2019-07-17 00:00:00")]
df8
df7
df10 = pd.concat([df7,df8,df9])
#df10 = df10.set_index("File name")
df10
# Out:
# Empty DataFrame
# Columns: [File name, Comment, Annotator's name, Start date , Start time, Finish date, Finish time, Net time spent on video (Dyn. objects), Net time spent on video (RB), Net time spent on video (total), Time for annotation corrections after not succeful validation, Annotation time in seconds. Automatic formula, Number of objects (počet oanotovaných objektů dynamika), Number of frames, Break (čas strávený na přestávkách), Net time spent on video manipulation, clarifications, internal meetings (anotátor), Ready for validation, Time of first validation, Name of first validator, Date of first validation, Results of first validation, Repair notes after first validation, Time of second validation , Name of second validator, Date of second validation, Results of second validation, Repair notes after second validation, Time of third validation, Name of third validator, Date of third validation, Results of third validation, Repair notes after third validation, Net time spent on video manipulation, clarifications, internal meetings (validátor), [min] per 1 dyn.obj., Annotation Ratio RB/1500fr. [min], Annotation Ratio NET/1500fr [min] filter, Validation time, Validation Ratio , Čas práce A vč. přestávek (hod.), Čas práce V (hod.) efektivní, Čas práce V (hod.) total, Finish time - start time, Rozdíl AQ vs. AO (kontrola pro anotátora)]
# Index: []
#
# [0 rows x 43 columns]

# %%
chyby = df[df["Rozdíl AQ vs. AO (kontrola pro anotátora)"] != 0 ].drop(0,axis =0)
chyby = chyby.loc[:, ["File name", "Annotator's name", "Start time" , "Finish time", "Break (čas strávený na přestávkách)",
              "Time for annotation corrections after not succeful validation", 
              "Net time spent on video (Dyn. objects)", 'Net time spent on video (RB)', 'Net time spent on video (total)',
              "Rozdíl AQ vs. AO (kontrola pro anotátora)"]
             ]
chyby.to_excel(r"C:\Users\anotator\Desktop\VALIDACE_KPI\data\evidence\honda\Chyby-23-07.xlsx")
