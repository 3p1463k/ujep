# %%
# !pip install simpledbf
# Out:
# ...
#   Running setup.py bdist_wheel for simpledbf ... done
#   Stored in directory: /home/evzen/.cache/pip/wheels/72/dd/df/cdfb970a508ef9750ebb4b6e035a3410c3d62b5a6a91d2aafc
# Successfully built simpledbf
# ...

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import pandas as pd
from simpledbf import Dbf5
import pathlib
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline 

dbf = Dbf5("/home/evzen/doc/proj/Jirka/obce1991/OBCE311.DBF",  codec = "CP852")

df = dbf.to_dataframe()

#dbf.to_csv("/home/evzen/doc/proj/Jirka/obce1991/OBCE311.csv")
df1 = df.iloc[:, 5:12]
df1.head()
# Out:
#      U8     U9  U10    U11   U12    U13  U14
# 0  1522  10979  386  12887  2109  12686  235
# 1    45     53    4    102    71     18    3
# 2     5      0    0      5     6      0    0
# 3     6      0    0      6     7      0    0
# 4     3      0    0      3     1      1    0

# %%
#kernel_density = sns.pairplot(df1, kind="kde")
regression_line = sns.pairplot(df1, kind="reg")
#print(kernel_density)
regression_line

# %%
df1.info
# Out:
# <bound method DataFrame.info of         U8     U9  U10    U11   U12    U13  U14
# 0     1522  10979  386  12887  2109  12686  235
# 1       45     53    4    102    71     18    3
# 2        5      0    0      5     6      0    0
# 3        6      0    0      6     7      0    0
# 4        3      0    0      3     1      1    0
# 5        1      0    0      1     0      0    0
# 6       14      0    0     14     2      0    0
# 7       78      9    8     95    34      2    0
# 8        6      0    0      6     2      0    0
# 9        9      0    0      9     2      0    0
# 10      28      0    0     28    16      0    0
# 11       5      1    0      6    16      5    0
# 12      13      0    0     13     3      1    2
# 13       2      0    0      2     1      0    0
# 14       4      1    0      5     3      0    0
# 15       2      0    0      2     3      0    0
# 16      30      1    1     32    15      1    0
# 17       5      4    0      9     4      0    0
# ...
